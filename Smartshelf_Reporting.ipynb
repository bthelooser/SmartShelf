# %% [markdown]
# <a href="https://colab.research.google.com/github/bthelooser/SmartShelf/blob/main/Smartshelf_Reporting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit plotly pyyaml
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 104.1 MB/s eta 0:00:00

# %%
# !python data_factory.py
# Out:
# Dummy data generated successfully in /data folder.

# %%
# 1. Start the app in the background
# !streamlit run app.py &>/content/logs.txt &

# 2. Extract your external IP (needed as a password for localtunnel)
import urllib
print("Password for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# 3. Expose to the internet
# !npx localtunnel --port 8501
# Out:
# Password for localtunnel is: 35.229.187.101
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇your url is: https://tricky-carpets-dance.loca.lt
# ^C
